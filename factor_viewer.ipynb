# %%
import pickle
import alphalens
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

# 解决画图时的中文乱码问题
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# 你想查看的因子名称 (必须和刚才跑完的 pkl 文件名对应)
TARGET_FACTOR = 'Liquidity'

# 定位你的 pkl 缓存文件
cache_file = f"PKL/{TARGET_FACTOR}_alphalens_cache.pkl"

# ==========================================
# 1. 瞬间加载数据 (开箱)
# ==========================================
print(f"📂 正在瞬间加载 {TARGET_FACTOR} 的缓存数据...")
with open(cache_file, 'rb') as f:
    factor_data = pickle.load(f)
print("✅ 加载成功！准备生成图表...")

# ==========================================
# 2. 召唤完全体图表瀑布流
# ==========================================
alphalens.tears.create_full_tear_sheet(factor_data)
# Out:
# 📂 正在瞬间加载 Liquidity 的缓存数据...
# ✅ 加载成功！准备生成图表...
# Quantiles Statistics
#                       min           max      mean       std  count    count %
# factor_quantile
# 1               -6.917662 -5.325753e-01 -1.795121  0.769858  60793  20.049933
# 2               -1.722780 -2.357266e-01 -0.725946  0.246819  60550  19.969790
# 3               -0.700253 -8.826273e-15 -0.253060  0.129576  60584  19.981003
# 4               -0.141069  9.381570e-01  0.185647  0.190241  60549  19.969460
# 5                0.239357  3.500958e+01  2.588051  2.866926  60732  20.029815
# Returns Analysis
#                                                   1D     5D    10D
# Ann. alpha                                     0.070  0.079  0.054
# beta                                           0.191  0.221  0.305
# Mean Period Wise Return Top Quantile (bps)     7.303  8.140  8.654
# Mean Period Wise Return Bottom Quantile (bps)  0.740  0.311  0.320
# Mean Period Wise Spread (bps)                  6.563  7.641  8.088
# Information Analysis
#                      1D     5D    10D
# IC Mean          -0.015 -0.015 -0.011
# IC Std.           0.092  0.084  0.081
# Risk-Adjusted IC -0.167 -0.177 -0.140
# t-stat(IC)       -3.270 -3.450 -2.731
# p-value(IC)       0.001  0.001  0.007
# IC Skew          -0.071 -0.026 -0.242
# IC Kurtosis      -0.063 -0.553 -0.619
# Turnover Analysis
#                               1D     5D    10D
# Quantile 1 Mean Turnover   0.021  0.081  0.142
# Quantile 2 Mean Turnover   0.052  0.195  0.318
# Quantile 3 Mean Turnover   0.064  0.219  0.333
# Quantile 4 Mean Turnover   0.056  0.200  0.312
# Quantile 5 Mean Turnover   0.024  0.091  0.161
#                                      1D     5D    10D
# Mean Factor Rank Autocorrelation  0.998  0.977  0.936
